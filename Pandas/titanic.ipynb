# %%
import numpy as np 
import pandas as pd

# %%
# read dataset using pandas 
data = pd.read_csv("Titanic-Dataset.csv")

# %%
#check first five row in over dataset
data.head()

# %%
#check last five row in over dataset
data.tail()

# %%
#check shape over dataset
data.shape

# %%
#check basic info over dataset
data.info()

# %%
data.describe()

# %%
data.describe(include="object")

# %%
data.describe(include="all")

# %%
data.corr()

# %%
data.corr(numeric_only=True)

# %%
data.columns

# %%
data.duplicated().sum()

# %%
data.iloc[0]

# %%
data.head(11)

# %%
data.iloc[10]

# %%
data.iloc[10:21]

# %%
#Specific rows and columns
data.iloc[0:5, 0:4]

# %%
data['Age']

# %%
#Select rows using condition
data.loc[data["Age"] > 50]

# %%
data['Pclass'].value_counts()

# %%
#Select specific columns
data.loc[data["Pclass"]==2, ["Name", "Age", "Sex","Cabin"]]

# %%
data['Survived'].value_counts()

# %%
#Passengers who survived
data.loc[data["Survived"] == 1]

# %%
data.loc[data["Survived"] == 0]

# %%
data['Survived'].value_counts()

# %%
data['Sex'].value_counts()

# %%
data.head(1)

# %%
#Age greater than 50
data[data["Age"] > 50]

# %%
data[data["Fare"] > 100]

# %%
data["Pclass"].value_counts()

# %%
#First-class passengers
data[data["Pclass"] == 1]

# %%
#Female passengers
data[data["Sex"] == "female"]

# %%
#Male passengers
data[data["Sex"] == "male"]

# %%
#Age > 30 AND female
data[(data["Age"] > 30) & (data["Sex"] == "female") & (data['Pclass']==3)]

# %%
data['Fare']

# %%
#Age > 30 OR Fare > 100
data[(data["Age"] > 30) | (data["Fare"] > 100)]

# %%
#Female AND survived
data[(data["Sex"] == "female") & (data["Survived"] == 1)]

# %%
data[(data["Sex"] == "male") & (data["Survived"] == 0)]

# %%
data['Embarked'].value_counts()

# %%
#Find passengers from first or second class:
data[data["Pclass"].isin([1, 2])]

# %%
data['Embarked']

# %%
#Find passengers who embarked from C or S:
data[data["Embarked"].isin(["C", "S"])]

# %% [markdown]
# ### query()

# %%
data.query("Age > 50")

# %%
data.query("Age > 30 and Fare > 50")

# %%
data.isnull()

# %%
data.isnull().sum()

# %%
(data.isnull().sum() / len(data)) * 100

# %%
data.notnull().sum()

# %%
data.head()

# %%
del data['PassengerId']

# %%
#Remove Columns
data.drop("Cabin", axis=1)

# %%
data.head()

# %%
#Permanently remove:
data.drop("Cabin", axis=1, inplace=True)

# %%
data.head()

# %%
#Multiple columns:
data.drop(["Cabin", "Ticket"], axis=1, inplace=True)

# %%
#Rename one column:
data.rename(columns={"Fare": "Ticket_Fare"}, inplace=True)

# %%
data.head()

# %%
#Rename Columns
data.rename(columns={
    "PassengerId": "Passenger_ID",
    "Survived": "Survival"
}, inplace=True)

# %%
data.head(1)

# %%
data['SibSp'].value_counts()

# %%
data['Parch'].value_counts()

# %%
#Add New Column
data["FamilySize"] = data["SibSp"] + data["Parch"] + 1

# %%
data.head()

# %%
data['FamilySize'].value_counts()

# %%
data.info()

# %%
data['Sex'].value_counts()

# %%
data["Sex"] = data["Sex"].map({
    0: "male",
    1: "female"
})

# %%
data.info()

# %%
data['Survived'].value_counts()

# %%
data["Sex"] = data["Sex"].map({
    "male": 0,
    "female": 1
})

# %%
data.head()

# %%
def age_group(age):
    if age < 18:
        return "Child"
    elif age < 60:
        return "Adult"
    else:
        return "Senior"

data["AgeGroup"] = data["Age"].apply(age_group)

# %%
data["AgeGroup"] = data["Age"].apply(
    lambda x: "Child" if x < 18 else "Adult"
)

# %%
#sort by age
data.sort_values("Age")

# %%
data.sort_values("Age", ascending=False)

# %%
data.sort_values(
    ["Pclass", "Fare"],
    ascending=[True, False]
)

# %%
data["Sex"].unique()

# %%
data["Sex"].value_counts()

# %%
data["Survived"].value_counts(normalize=True) * 100

# %% [markdown]
# ### Statistical Operations

# %%
data["Age"].mean()

# %%
data["Age"].median()

# %%
data["Age"].mode()

# %%
data["Age"].min()

# %%
data["Age"].max()

# %%
#Standard deviation
data["Age"].std()

# %%
data["Age"].var()

# %%
data["Fare"].sum()

# %% [markdown]
# ###  GroupBy

# %%
data.groupby("Sex")["Age"].mean()

# %%
data.groupby("Pclass")["Fare"].median()

# %%
data.groupby("Pclass")["Survived"].mean()

# %%
data.groupby("Sex")["Survived"].mean()

# %%
data.groupby("Pclass").agg({
    "Age": "mean",
    "Fare": "mean",
    "Survived": "sum"
})

# %% [markdown]
# ## GroupBy Multiple Columns

# %%
data.groupby(["Sex", "Pclass"])["Age"].mean()

# %%
data.groupby(["Sex", "Pclass"]).agg({
    "Age": "mean",
    "Fare": "mean"
})

# %%
#pivot_table()
pd.pivot_table(
    data,
    values="Survived",
    index="Sex",
    columns="Pclass",
    aggfunc="mean"
)

# %%
data.head(1)

# %%
pd.pivot_table(
    data,
    values="Age",
    index="Sex",
    columns="Pclass",
    aggfunc="count"
)

# %%
#String Operations
data[data["Name"].str.contains("Mr")]

# %%
data[data["Name"].str.contains("Mrs")]

# %%
data["Title"] = data["Name"].str.extract(r",\s*([^.]*)\.")

# %%
data.head()

# %%
data['Title'].value_counts()

# %%
data['Sex'].value_counts()

# %%
data['Sex'] = data["Sex"].replace({
    "male": "M",
    "female": "F"
})

# %%
data['Sex'].value_counts()

# %%
data['Cabin'].value_counts(())

# %%
data.head(10)

# %%
data["Cabin"].replace(
    {None: "Unknown"}
)

# %%
import numpy as np

data["SurvivalStatus"] = np.where(
    data["Survived"] == 1,
    "Survived",
    "Not Survived"
)

# %%
data['SurvivalStatus'].value_counts()

# %%
df2 = data.copy()

# %%
df2.head()

# %%
df1 = data[["PassengerId", "Name"]]
df2 = data[["PassengerId", "Survived"]]

result = pd.merge(
    df1,
    df2,
    on="PassengerId",
    how="inner"
)

pd.merge(df1, df2, how="inner")
pd.merge(df1, df2, how="left")
pd.merge(df1, df2, how="right")
pd.merge(df1, df2, how="outer")

# %%
result
# Out:
#      PassengerId                                               Name  Survived
# 0              1                            Braund, Mr. Owen Harris         0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2              3                             Heikkinen, Miss. Laina         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4              5                           Allen, Mr. William Henry         0
# ..           ...                                                ...       ...
# 886          887                              Montvila, Rev. Juozas         0
# 887          888                       Graham, Miss. Margaret Edith         1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"         0
# 889          890                              Behr, Mr. Karl Howell         1
# 890          891                                Dooley, Mr. Patrick         0
#
# [891 rows x 3 columns]

# %%
df1.
# Out:
#    PassengerId                                               Name
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5                           Allen, Mr. William Henry

# %%
df2.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
pd.merge(df1, df2, how="inner")
pd.merge(df1, df2, how="left")
pd.merge(df1, df2, how="right")
pd.merge(df1, df2, how="outer")

# %%
data.to_csv("Titanic_Cleaned.csv", index=False)

# %%
data.to_excel("Titanic_Cleaned.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data.to_excel("Titanic_Cleaned.xlsx", index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)'))': /simple/openpyxl/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)'))': /simple/openpyxl/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)'))': /simple/openpyxl/
# ...
