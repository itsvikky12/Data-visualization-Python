# %% [markdown]
# # ***What is Matplotlib?***
# Matplotlib is a Python library used to create:
# Line Charts
# Bar Charts
# Pie Charts
# Scatter Plots
# Histograms
# Box Plots
# Area Charts
# Heatmaps (with other libraries)
# It helps you visualize data, making patterns and trends easier to understand.

# %% [markdown]
# # ***Installation***

# %%
pip install matplotlib

# %%
#import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Your First Graph***

# %%
x = [1,2,3,4,5]
y = [10,20,15,30,25]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # **Line Chart**

# %%
import matplotlib.pyplot as plt

months = ["Jan","Feb","Mar","Apr","May"]
sales = [100,150,120,180,200]

plt.plot(months, sales)
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
#Change Line Style
plt.plot(
    months,
    sales,
    color="red",
    linestyle="--",
    linewidth=2,
    marker="o"
)

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May"]

sales_2025 = [100, 150, 120, 180, 220]
sales_2026 = [120, 170, 160, 200, 250]

plt.plot(months, sales_2025, marker="o")
plt.plot(months, sales_2026, marker="s")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend("center")
plt.show()

# %%
plt.plot(
    months,
    sales_2025,
    label="2025"
)

plt.plot(
    months,
    sales_2026,
    label="2026"
)

plt.legend("upper right") 
#"upper right"
#"upper left"
#"lower right"
#"lower left"
#"center"


plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
import matplotlib.pyplot as plt

students = ["Vikky","Rahul","Aman","Neha"]
marks = [85,90,78,95]

plt.bar(students, marks,width=0.6)
plt.title("Student Marks")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %%
#Horizontal Bar Chart
plt.barh(students, marks)
plt.show()

# %%
#Multiple Bar Charts
students = ["A", "B", "C", "D"]

python = [80, 70, 90, 60]
java = [70, 75, 85, 80]

import numpy as np

x = np.arange(len(students))
width = 0.35

plt.bar(x - width/2, python, width, label="Python")
plt.bar(x + width/2, java, width, label="Java")
plt.xticks(x, students)

plt.legend()

plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
import matplotlib.pyplot as plt

subjects = ["AI","Python","Java","SQL"]
hours = [35,25,20,20]
explode = [0.1, 0, 0, 0]
mycolors = ["Red", "hotpink", "b", "#4CAF50"]

plt.pie(hours, 
labels=subjects, 
autopct="%1.1f%%", #Percentage in Pie Chart
explode=explode, #Explode Pie Chart
shadow = True, #add shadow 
colors = mycolors #add colors
)
plt.title("Study Time")
plt.legend()
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
import matplotlib.pyplot as plt

height = [150,155,160,165,170]
weight = [50,55,60,65,70]

plt.scatter(height, weight,
 s=100 ,#Scatter Plot Size
alpha=0.5 #Scatter Plot Transparency

)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height vs Weight")
plt.show()

# %% [markdown]
# # **Histogram**

# %%
#Shows how data is distributed.
import matplotlib.pyplot as plt

marks = [55,60,65,70,75,80,85,90,95,81,97,49,30,20,10,56,70,60,89,37,50,70,46]

plt.hist(marks, 
bins=5
)
plt.title("Marks Distribution")
plt.show()

# %% [markdown]
# # **Box Plot**
#
#
# Useful for finding:
# Median
# Quartiles
# Outliers

# %%
import matplotlib.pyplot as plt

marks = [55,60,65,70,75,80,85,90,95,81,97,49,30,20,10,56,70,60,89,37,50,70,46]

plt.boxplot(marks)
plt.title("Marks")
plt.show()

# %%
python = [70, 75, 80, 85, 90]
java = [60, 65, 70, 75, 80]
cpp = [65, 70, 75, 80, 85]

plt.boxplot(
    [python, java, cpp],
    labels=["Python", "Java", "C++"]
)

plt.show()
# Out:
# /var/folders/x8/xtqv5kzs0wbgyt79__b8kpmw0000gn/T/ipykernel_1992/3611516293.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %% [markdown]
# # **Grid**

# %%
#Adds grid lines to improve readability.
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.figure(figsize= (5,2)) #using for figsize
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# ### Display Multiple Plots (SubPlot)

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Titanic-Dataset.csv')

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
avg_fare = data.groupby("Pclass")["Fare"].mean()
print(avg_fare.index)
print(avg_fare.values)
# Out:
# Index([1, 2, 3], dtype='int64', name='Pclass')
# [84.1546875  20.66218315 13.6755501 ]

# %%
avg_fare = data.groupby("Pclass")["Fare"].mean()

plt.plot(avg_fare.index, avg_fare.values, marker="o")

plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")

plt.show()

# %%
avg_fare = data.groupby("Sex")["Fare"].mean()

plt.plot(avg_fare.index, avg_fare.values, marker="o")

plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")

plt.show()

# %%
passengers = data["Pclass"].value_counts().sort_index()

print(passengers.index, passengers.values)
# Out:
# Index([1, 2, 3], dtype='int64', name='Pclass') [216 184 491]

# %%
passengers = data["Pclass"].value_counts().sort_index()

plt.bar(passengers.index, passengers.values)

plt.title("Passengers by Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")

plt.show()

# %%
plt.hist(data["Age"].dropna(), bins=20)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")

plt.show()

# %%
plt.scatter(data["Age"], data["Fare"])

plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.scatter(
    data["Age"],          # Column 1 → X-axis
    data["Fare"],         # Column 2 → Y-axis
    c=data["Pclass"]*50,  # Column 3 → Point size
    alpha=0.6,
    marker="o",
    edgecolors="black"
)

plt.title("Age vs Fare by Passenger Class")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

# %%
age_data = [
    data[data["Pclass"] == 1]["Age"].dropna(),
    data[data["Pclass"] == 2]["Age"].dropna(),
    data[data["Pclass"] == 3]["Age"].dropna()
]

plt.boxplot(age_data)

plt.title("Age Distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Age")

plt.show()

# %%
survival = data["Survived"].value_counts()

plt.pie(
    survival,
    labels=["Not Survived", "Survived"],
    autopct="%1.1f%%"
)

plt.title("Titanic Survival Distribution")

plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.hist(data["Age"].dropna(), bins=20)
plt.title("Age Distribution")

plt.subplot(2, 2, 2)
plt.bar(
    data["Pclass"].value_counts().sort_index().index,
    data["Pclass"].value_counts().sort_index().values
)
plt.title("Passengers by Class")

plt.subplot(2, 2, 3)
plt.scatter(data["Age"], data["Fare"])
plt.title("Age vs Fare")

plt.subplot(2, 2, 4)
survival = data["Survived"].value_counts()
plt.pie(
    survival,
    labels=["Not Survived", "Survived"],
    autopct="%1.1f%%"
)
plt.title("Survival")

plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Missing values in each column
print(data.isnull().sum())

# Total missing values
print(data.isnull().sum().sum())

# Percentage of missing values
print(data.isnull().mean() * 100)

# %%
#Remove missing values
data.dropna(inplace=True)

# %%
#Remove rows where a particular column is missing:
data.dropna(subset=["Age"], inplace=True)

# %%
#Fill with a fixed value
data["Age"] = data["Age"].fillna(25)

# %%
data["Gender"] = data["Gender"].fillna("Unknown")

# %%
#Mean — Numerical Data
data["Age"] = data["Age"].fillna(data["Age"].mean())

# %%
#Median — Numerical Data : Usually better when there are outliers.
data["Age"] = data["Age"].fillna(data["Salary"].median())

# %%
#Mode — Categorical Data : For categorical columns such as Gender, City, Department, etc.
data["Gender"] = data["Gender"].fillna(data["Gender"].mode()[0])

# %%
#Forward Fill — ffill() : Uses the previous value. Time-series data
data["Temperature"] = data["Temperature"].ffill()

# %%
#Backward Fill — bfill() : Uses the next available value : Time-series data
data["Temperature"] = data["Temperature"].bfill()

# %%
numeric_cols = data.select_dtypes(include="number").columns

data[numeric_cols] = data[numeric_cols].fillna(
    data[numeric_cols].mean()
)

# %%
categorical_cols = data.select_dtypes(include="object").columns

for col in categorical_cols:
    data[col] = data[col].fillna(data[col].mode()[0])
