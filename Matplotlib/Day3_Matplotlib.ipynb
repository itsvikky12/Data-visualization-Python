# %% [markdown]
# # ***What is Matplotlib?***
# Matplotlib is a Python library used to create:
# Line Charts
# Bar Charts
# Pie Charts
# Scatter Plots
# Histograms
# Box Plots
# Area Charts
# Heatmaps (with other libraries)
# It helps you visualize data, making patterns and trends easier to understand.

# %% [markdown]
# # ***Installation***

# %%
pip install matplotlib

# %%
#import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Your First Graph***

# %%
x = [1,2,3,4,5]
y = [10,20,15,30,25]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # **Line Chart**

# %%
import matplotlib.pyplot as plt

months = ["Jan","Feb","Mar","Apr","May"]
sales = [100,150,120,180,200]

plt.plot(months, sales)
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
#Change Line Style
plt.plot(
    months,
    sales,
    color="red",
    linestyle="--",
    linewidth=2,
    marker="o"
)

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May"]

sales_2025 = [100, 150, 120, 180, 220]
sales_2026 = [120, 170, 160, 200, 250]

plt.plot(months, sales_2025, marker="o")
plt.plot(months, sales_2026, marker="s")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend("center")
plt.show()

# %%
plt.plot(
    months,
    sales_2025,
    label="2025"
)

plt.plot(
    months,
    sales_2026,
    label="2026"
)

plt.legend("upper right") 
#"upper right"
#"upper left"
#"lower right"
#"lower left"
#"center"


plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
import matplotlib.pyplot as plt

students = ["Vikky","Rahul","Aman","Neha"]
marks = [85,90,78,95]

plt.bar(students, marks,width=0.6)
plt.title("Student Marks")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %%
#Horizontal Bar Chart
plt.barh(students, marks)
plt.show()

# %%
#Multiple Bar Charts
students = ["A", "B", "C", "D"]

python = [80, 70, 90, 60]
java = [70, 75, 85, 80]

import numpy as np

x = np.arange(len(students))
width = 0.35

plt.bar(x - width/2, python, width, label="Python")
plt.bar(x + width/2, java, width, label="Java")

plt.xticks(x, students)

plt.legend()

plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
import matplotlib.pyplot as plt

subjects = ["AI","Python","Java","SQL"]
hours = [35,25,20,20]
explode = [0.1, 0, 0, 0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(hours, 
labels=subjects, 
#autopct="%1.1f%%", #Percentage in Pie Chart
explode=explode, #Explode Pie Chart
shadow = True, #add shadow 
colors = mycolors #add colors
)
plt.title("Study Time")
#plt.legend()
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
import matplotlib.pyplot as plt

height = [150,155,160,165,170]
weight = [50,55,60,65,70]

plt.scatter(height, weight,
# s=100 #Scatter Plot Size
alpha=0.5 #Scatter Plot Transparency

)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height vs Weight")
plt.show()

# %% [markdown]
# # **Histogram**

# %%
#Shows how data is distributed.
import matplotlib.pyplot as plt

marks = [55,60,65,70,75,80,85,90,95]

plt.hist(marks, bins=5)
plt.title("Marks Distribution")
plt.show()

# %% [markdown]
# # **Box Plot**

# %%
"""
Useful for finding:
Median
Quartiles
Outliers
"""

import matplotlib.pyplot as plt

marks = [50,55,60,70,75,80,85,90,100]

plt.boxplot(marks)
plt.title("Marks")
plt.show()

# %%
python = [70, 75, 80, 85, 90]
java = [60, 65, 70, 75, 80]
cpp = [65, 70, 75, 80, 85]

plt.boxplot(
    [python, java, cpp],
    labels=["Python", "Java", "C++"]
)

plt.show()
# Out:
# /var/folders/x8/xtqv5kzs0wbgyt79__b8kpmw0000gn/T/ipykernel_1755/3611516293.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %% [markdown]
# # **Grid**

# %%
#Adds grid lines to improve readability.
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

#plt.grid(axis = 'x')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# ### Display Multiple Plots (SubPlot)

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()
