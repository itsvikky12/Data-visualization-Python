# %% [markdown]
# # **Pandas**

# %% [markdown]
# # What is Pandas?
# Pandas is a Python library used for data manipulation and analysis. It makes it easy to work with structured data such as CSV files, Excel sheets, SQL tables, and JSON data.

# %% [markdown]
# With Pandas, you can:
#    1. Read CSV or Excel files
#    2. Filter rows
#    3. Select columns
#    4. Calculate averages
#    5. Handle missing values
#    6. Sort data
#    7. Group data
#    8. Merge multiple datasets
#    9. Prepare data for Machine Learning

# %% [markdown]
# # **Install Pandas**

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 324 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 812 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 440 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # **1. Series (1D)**

# %%
import pandas as pd

marks = pd.Series([80, 90, 95, 88])

print(marks)
# Out:
# 0    80
# 1    90
# 2    95
# 3    88
# dtype: int64

# %% [markdown]
# # **2. DataFrame (2D)**

# %%
import pandas as pd

data = {
    "Name": ["Vikky", "Rahul", "Aman"],
    "Age": [22, 21, 23],
    "Marks": [95, 88, 91]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age  Marks
# 0  Vikky   22     95
# 1  Rahul   21     88
# 2   Aman   23     91

# %%
data = pd.re

# %% [markdown]
# # **Reading Data**
# CSV

# %%
df = pd.read_csv("students.csv")

# %%
df = pd.read_excel("students.xlsx")

# %%
#check first five row 
df.head()

#check last five row 
#df.tail()

#check info
#df.info()

#Statistics 
#df.describe()

#check shape of the data
#df.shape

#check how may columns in data
#df.columns

#check type of the dataset
#df.dtypes

#check value counts 
#df.value_counts()

#check unique value in this dataset
#df.unique()

#short data
#df.sort_values()
#groupby

#df.groupby()

#df.merge()
#df.drop()
#df.fillna()
#df.isnull()

# %% [markdown]
# # **Selecting Columns**
# Single column

# %%
df["Marks"]

# %%
#Multiple Columns
df[["Name", "Marks"]]

# %% [markdown]
# # **Selecting Rows**
# Using position (iloc)

# %%
df.iloc[0]

# %%
#first two rows
df.iloc[0:2]

# %%
#Using labels
df.loc[0]

# %% [markdown]
# # **Filtering Data**
# Students with marks greater than 90

# %% [markdown]
# df[df["Marks"] > 90]

# %%
#Multiple conditions
df[(df["Marks"] > 90) & (df["Age"] > 21)]

# %% [markdown]
# # **Adding a Column**

# %% [markdown]
# df["Grade"] = ["A", "B", "A"]

# %% [markdown]
# # **Updating Values**

# %%
df.loc[0, "Marks"] = 99

# %% [markdown]
# # **Deleting Columns**

# %%
df.drop("Grade", axis=1)

# %% [markdown]
# # **Sorting**
# Ascending

# %%
df.sort_values("Marks")
